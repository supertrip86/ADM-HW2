# %%
import pandas as pd
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import functions

# %% [markdown]
# ## Question RQ2 - 1
#
# - What are the categories of the most trending products overall? For each month visualize this information through a plot showing the number of sold products per category
#
# Making use of some bash commands, we extract from the orginal csv files only the relevant data to create two new files (the rq2 versions indicated below), containing only the rows labelled as "purchase", grouped by each category.
# We join (concat) these two files into a single one, and we plot the result, which shows the most sold products

# %%
csv_list = ['../../archive/2019-Oct.csv.rq2.csv', '../../archive/2019-Nov.csv.rq2.csv']
df_list = []

for filename in csv_list:
    df_list.append(pd.read_csv(filename, names=['category','sales'], header=None))

df = pd.concat(df_list)

ax = df.plot(figsize=(16,6))
ax.set_xticks(range(len(df.category.values)))
ax.set_xticklabels(df.category.values, rotation=90)
ax.plot()
# Out:
# []

# %% [markdown]
# We can also focus over the most sold products:

# %%
ax = df.plot(figsize=(16,6))
ax.set_xticks(range(len(df.category.values)))
ax.set_xticklabels(df.category.values, rotation=90)
ax.plot()
plt.xlim(80, 110)
# Out:
# (80.0, 110.0)

# %% [markdown]
# ## Question RQ2 - 2
#
# - Plot the most visited subcategories.
#
# We first split the 'category string' into separate subcategories. If a subcategory actually exists, we take it as a reference, otherwise we use the main one.
# We group the data based on the target (sub)category by means of the "Counter" library. Eventually, we plot the result.

# %%
subcategories = df.category.apply(lambda x: x.split('.')[1] if len(x.split('.')) > 1 else x.split('.')[0])
count = Counter(list(zip(subcategories)))

plt.figure(figsize=[16,5])
plt.xticks(range(len(count)), labels=count.keys(), rotation='vertical')
plt.bar(range(len(count)), count.values())
# Out:
# <BarContainer object of 59 artists>

# %% [markdown]
# ## Question RQ2 - 3
#
# - What are the 10 most sold products per category?
#
# From the dataset, we sort the values by "sales", in descending order, then print to screen the first 10 results.

# %%
df.sort_values(by=['sales'],ascending=False).head(10)
# Out:
#                           category   sales
# 98          electronics.smartphone  382647
# 93          electronics.smartphone  338018
# 91     electronics.audio.headphone   40834
# 86     electronics.audio.headphone   30503
# 102           electronics.video.tv   30274
# 97              electronics.clocks   23237
# 97            electronics.video.tv   21565
# 48       appliances.kitchen.washer   19772
# 71              computers.notebook   18433
# 27   appliances.environment.vacuum   18193
